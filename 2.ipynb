# %%
import pandas as pd

# Load the CSV file
file_path = "llm_outputs/llm_markdown_table_results.csv"
df = pd.read_csv(file_path)
df
# Out:
#                                                   query  rank  \
# 0     hdflow: enhancing llm complex problem-solving ...     1
# 1     farstail: a persian natural language inference...     1
# 2            tibert: tibetan pre-trained language model     1
# 3     moment: a family of open time-series foundatio...     1
# 4     anti-money laundering datasets: inpluslab anti...     1
# ...                                                 ...   ...
# 4552  llava-med: training a large language-and-visio...     1
# 4553  question rewriting? assessing its importance f...     1
# 4554  magpie: alignment data synthesis from scratch ...     1
# 4555  transfer learning of transformer-based speech ...     1
# 4556  multi-modal auto-regressive modeling via visua...     1
#
#                                         retrieved_title   corpusid  \
# 0     hdflow: enhancing llm complex problem-solving ...  272911172
# 1     farstail: a persian natural language inference...  221802461
# ...
